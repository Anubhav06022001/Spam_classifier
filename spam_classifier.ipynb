# %%
import pandas as pd
import numpy as np
import sklearn

# %%
df=pd.read_csv("spam.csv", encoding="ISO-8859-1")
#The `encoding="ISO-8859-1"` helps read the file properly by handling special characters that the default setting might not understand.

# %%
df.sample(5)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 4844   ham                  Missing you too.pray inshah allah        NaN
# 4335   ham  Fyi I'm taking a quick shower, be at epsilon i...        NaN
# 513    ham                          No..jst change tat only..        NaN
# 3627   ham  Meeting u is my work. . . Tel me when shall i ...        NaN
# 5467  spam  Get your garden ready for summer with a FREE s...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 4844        NaN        NaN
# 4335        NaN        NaN
# 513         NaN        NaN
# 3627        NaN        NaN
# 5467        NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.shape
# Out:
# (5572, 5)

# %%
# 1) data cleaning
#2) EDA
# 3) text preprocesing
# 4) modle building
# 5) evaluation
# 6) improvements
# 7) website
# 8) depl0y

# %% [markdown]
# ### 1) data cleaning

# %%
df.drop(columns=["Unnamed: 2","Unnamed: 3","Unnamed: 4"],inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 2068  ham  Its hard to believe things like this. All can ...
# 566   ham      Oooh bed ridden ey? What are YOU thinking of?
# 3018  ham                 Wat time do u wan 2 meet me later?
# 792   ham  Y?WHERE U AT DOGBREATH? ITS JUST SOUNDING LIKE...
# 3404  ham                             Jus chillaxin, what up

# %%
df.rename(columns={'v1':'target','v2':'text'},inplace=True)
#The `inplace=True` makes the changes directly to the original DataFrame without needing to create a new one.

# %%
df.sample(2)
# Out:
#      target                                               text
# 4735    ham   Not for possession, especially not first offense
# 4976    ham  A boy was late 2 home. His father: \POWER OF F...

# %%
from sklearn.preprocessing import LabelEncoder
encoder= LabelEncoder()

# %%
df['target']= encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df=df.drop_duplicates(keep='first')

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# ### EDA

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(),labels=['ham','spam'],autopct="%0.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x1aa2ba71b20>,
#   <matplotlib.patches.Wedge at 0x1aa2ba71a30>],
#  [Text(-1.0144997251399075, 0.4251944351600247, 'ham'),
#   Text(1.014499764949479, -0.4251943401757036, 'spam')],
#  [Text(-0.5533634864399495, 0.23192423736001344, '87.37'),
#   Text(0.5533635081542612, -0.23192418555038377, '12.63')])

# %%
# data is imbalanced

# %%
# !pip install nltk
import nltk
# Out:
# Requirement already satisfied: nltk in d:\sensorproject\venv\lib\site-packages (3.9.1)
# Requirement already satisfied: click in d:\sensorproject\venv\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in d:\sensorproject\venv\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\sensorproject\venv\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in d:\sensorproject\venv\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in d:\sensorproject\venv\lib\site-packages (from click->nltk) (0.4.6)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\anubh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df.columns
# Out:
# Index(['target', 'text'], dtype='object')

# %%
df['num_characters']= df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
df['num_words']= df['text'].apply(lambda x:len(nltk.word_tokenize(x)))
df['num_sentences']= df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df.columns
# Out:
# Index(['target', 'text', 'num_characters', 'num_words', 'num_sentences'], dtype='object')

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    18.455794       1.965564
# std         58.236293    13.324758       1.448541
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
df[df['target']==0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
df[df['target']==1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
import seaborn as sns
sns.histplot(df[df['target']==0]['num_characters'])
sns.histplot(df[df['target']==1]['num_characters'],color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
sns.heatmap(df[['target','num_characters','num_words','num_sentences']].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# DATA PREPROCESSING
#
#     lowercase
#
#     tokenization
#
#     removing special chaarachters
#
#     removing step words and punctuation
#
#     stemming

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anubh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import string

# %%
# y[:] copies all elements from list y into a new list without modifying the original.

def transform_text(text):
    text=text.lower()
    text = nltk.word_tokenize(text)
    
    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
    
    text=y[:]
    y.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
            
    text= y[:]
    y.clear()
    
    for i in text:
        y.append(ps.stem(i))
        
    return " ".join(y)

# %%
df['transformed_text']=df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
# !pip install Wordcloud
from wordcloud import WordCloud
# Out:
# Requirement already satisfied: Wordcloud in d:\sensorproject\venv\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in d:\sensorproject\venv\lib\site-packages (from Wordcloud) (1.24.4)
# Requirement already satisfied: pillow in d:\sensorproject\venv\lib\site-packages (from Wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in d:\sensorproject\venv\lib\site-packages (from Wordcloud) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in d:\sensorproject\venv\lib\site-packages (from matplotlib->Wordcloud) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in d:\sensorproject\venv\lib\site-packages (from matplotlib->Wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\sensorproject\venv\lib\site-packages (from matplotlib->Wordcloud) (4.54.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\sensorproject\venv\lib\site-packages (from matplotlib->Wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in d:\sensorproject\venv\lib\site-packages (from matplotlib->Wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\sensorproject\venv\lib\site-packages (from matplotlib->Wordcloud) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in d:\sensorproject\venv\lib\site-packages (from matplotlib->Wordcloud) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in d:\sensorproject\venv\lib\site-packages (from matplotlib->Wordcloud) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in d:\sensorproject\venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->Wordcloud) (3.20.2)
# Requirement already satisfied: six>=1.5 in d:\sensorproject\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->Wordcloud) (1.16.0)

# %%
import collections
from collections import Counter

# %%
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
spam_wc = wc.generate(df[df['target'] == 1]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(spam_wc)

# %%
ham_wc = wc.generate(df[df['target'] == 0]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(ham_wc)

# %%
spam_corpus = []
for msg in df[df['target'] == 1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
sns.barplot(x=pd.DataFrame(Counter(spam_corpus).most_common(30))[0], y=pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()

# %%
ham_corpus = []
for msg in df[df['target'] == 0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35404

# %%
sns.barplot(x=pd.DataFrame(Counter(ham_corpus).most_common(30))[0], y=pd.DataFrame(Counter(ham_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %% [markdown]
# ### MODEl BUILDING

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
cv= CountVectorizer()
tfidf= TfidfVectorizer(max_features=3000)

# %%
X=tfidf.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y=df['target'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
#very bad output obtained
# Out:
# 0.8694390715667312
# [[788 108]
#  [ 27 111]]
# 0.5068493150684932

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# still better
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# good
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
# due to imbalance data we prefer accuracy 
# tfidf,mnb used

# %%
import pickle

# %%
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
